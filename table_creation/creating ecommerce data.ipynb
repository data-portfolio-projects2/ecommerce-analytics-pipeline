# %%
from faker import Faker
fake = Faker()

# %%
import pandas as pd
customer_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    cust_code = 'CUST' + fakecode
    customer_code.append(cust_code)
    
ecommerce = pd.Series(customer_code, name='customer_id')

# %%
product_code = []
for _ in range(30):
    fakecode2 = fake.postcode()
    prod = 'PROD' + fakecode2
    product_code.append(prod)
    
product_id = pd.Series(product_code, name='product_id')
ecommerce = pd.concat([ecommerce, product_id], axis=1)

# %%
order_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    ord_code = 'ORDR' + fakecode
    order_code.append(ord_code)
    
ecommerce['order_id'] = pd.Series(order_code, name='order_id')

# %%
order_item_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    ord_itm_code = ['ORDR00' + fakecode + '-0' + str(i) for i in range(1, 1001)]
    for x in ord_itm_code:
            order_item_code.append(x)
ecommerce['order_item_id'] = pd.Series(order_item_code, name='order_item_id')

# %%
campaign_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    cmp_code = 'CMP' + fakecode
    campaign_code.append(cmp_code)
    
ecommerce['campaign_id'] = pd.Series(campaign_code, name='campaign_id')

# %%
customer_name = []
for _ in range(1000):
    fakename = fake.name()
    customer_name.append(fakename)
   
ecommerce['customer_name'] = pd.Series(customer_name, name='customer_name')

# %%
date_code = []
for _ in range(1000):
    fakedate = fake.date_between(start_date='-2y', end_date='today')
    date_code.append(fakedate)

ecommerce['date'] = pd.Series(date_code, name='date')

# %%
import random

products = [
    "FreePrints 4x6 Photo Print",
    "FreePrints Square Photo Print",
    "FreePrints Glossy Photo Print",
    "FreePrints Matte Photo Print",
    "FreePrints 8x10 Photo Print",
    "FreePrints Hardcover Photobook",
    "FreePrints Softcover Photobook",
    "FreePrints Layflat Photobook",
    "FreePrints Mini Photobook",
    "FreePrints Wall Calendar",
    "Personalized Holiday Greeting Card",
    "Custom Wedding Invitation Card",
    "Birth Announcement Card",
    "Thank You Card with Photo",
    "Foil-Pressed Greeting Card",
    "Personalized Business Card",
    "Personalized Photo Mug",
    "Custom Name Necklace",
    "Personalized Photo Blanket",
    "Engraved Wooden Keepsake Box",
    "Personalized Cutting Board",
    "Custom Photo Pillow",
    "Custom Printed T-Shirt",
    "Personalized Hoodie",
    "Custom Coffee Mug",
    "Personalized Phone Case",
    "Custom Tote Bag",
    "Personalized Children’s Storybook",
    "Custom Name Puzzle Book",
    "Personalized Birthday Storybook"
]

# ------------------------------
# Create Product Dimension DataFrame
# ------------------------------
# product_dim stores the mapping of product IDs to product names
# - 'product_id': list of unique product IDs (generated earlier)
# - 'product_name': corresponding list of product names
product_dim = pd.DataFrame({
    'product_id': product_code,          # your generated product_ids
    'product_name': products             # the 30 product names
})

# ------------------------------
# Repeat product IDs to match ecommerce dataframe length
# ------------------------------
# ecommerce has more rows than unique products (e.g., 1000 rows vs 30 products)
# repeats = number of times to repeat product list to cover all rows
# len(ecommerce) // 30 → number of full sets of 30 products
# +1 → ensures extra IDs to cover remainder rows
repeats = len(ecommerce) // 30 + 1

# product_code * repeats → repeats the product list 'repeats' times
# [:len(ecommerce)] → slice to ensure exactly one product ID per row
product_ids_rows = (product_code * repeats)[:len(ecommerce)]

# ------------------------------
# Shuffle product IDs randomly
# ------------------------------
# random.shuffle ensures product distribution is random across rows
random.shuffle(product_ids_rows)

# ------------------------------
# Assign shuffled product IDs to ecommerce dataframe
# ------------------------------
# Each row in ecommerce now has a product_id
ecommerce['product_id'] = product_ids_rows

ecommerce = ecommerce.merge(product_dim, on='product_id', how='left')

# %%
unique_id = ecommerce['product_id'].unique()
unique_product = ecommerce['product_name'].unique()

product_dict = dict(zip(unique_id, unique_product))
product_dict
# Out:
# {'PROD52816': 'Birth Announcement Card',
#  'PROD19552': 'Custom Printed T-Shirt',
#  'PROD65121': 'FreePrints 8x10 Photo Print',
#  'PROD48112': 'Thank You Card with Photo',
#  'PROD06242': 'Personalized Photo Mug',
#  'PROD77393': 'Foil-Pressed Greeting Card',
#  'PROD53436': 'Personalized Hoodie',
#  'PROD56956': 'Personalized Children’s Storybook',
#  'PROD29689': 'FreePrints Wall Calendar',
#  'PROD14391': 'FreePrints Square Photo Print',
#  'PROD85578': 'Custom Wedding Invitation Card',
#  'PROD03017': 'Engraved Wooden Keepsake Box',
#  'PROD06268': 'FreePrints Matte Photo Print',
#  'PROD57981': 'Custom Tote Bag',
#  'PROD21422': 'Personalized Holiday Greeting Card',
#  'PROD33500': 'Custom Coffee Mug',
#  'PROD05758': 'Custom Name Puzzle Book',
#  'PROD12177': 'Personalized Cutting Board',
#  'PROD79582': 'Custom Photo Pillow',
#  'PROD03875': 'Personalized Business Card',
#  'PROD08816': 'Personalized Birthday Storybook',
#  'PROD95035': 'FreePrints Layflat Photobook',
#  'PROD45287': 'FreePrints Mini Photobook',
#  'PROD26075': 'FreePrints 4x6 Photo Print',
#  'PROD11126': 'FreePrints Hardcover Photobook',
#  'PROD31446': 'Custom Name Necklace',
#  'PROD88120': 'Personalized Phone Case',
#  'PROD84018': 'FreePrints Glossy Photo Print',
#  'PROD11127': 'FreePrints Softcover Photobook',
#  'PROD80319': 'Personalized Photo Blanket'}

# %%
import numpy as np
channels = ['Social', 'Paid_Search', 'Email']

ecommerce['channel_name'] = np.random.choice(channels, size=len(ecommerce))

channel_dict = {
    'Social': 'CHNL_01',
    'Paid_Search': 'CHNL_02',
    'Email': 'CHNL_03'
}

ecommerce['channel_id'] = ecommerce['channel_name'].map(channel_dict)

# %%
# Generate a random floating-point number between 5 and 150, then round it to 2 decimal places
price_dict = {product: round(random.uniform(5, 150), 2) for product in products}
price_dict
# Out:
# {'FreePrints 4x6 Photo Print': 54.28,
#  'FreePrints Square Photo Print': 81.49,
#  'FreePrints Glossy Photo Print': 140.77,
#  'FreePrints Matte Photo Print': 140.71,
#  'FreePrints 8x10 Photo Print': 115.66,
#  'FreePrints Hardcover Photobook': 135.29,
#  'FreePrints Softcover Photobook': 131.53,
#  'FreePrints Layflat Photobook': 9.23,
#  'FreePrints Mini Photobook': 10.29,
#  'FreePrints Wall Calendar': 11.79,
#  'Personalized Holiday Greeting Card': 92.25,
#  'Custom Wedding Invitation Card': 103.33,
#  'Birth Announcement Card': 143.38,
#  'Thank You Card with Photo': 78.06,
#  'Foil-Pressed Greeting Card': 44.37,
#  'Personalized Business Card': 41.47,
#  'Personalized Photo Mug': 97.59,
#  'Custom Name Necklace': 58.57,
#  'Personalized Photo Blanket': 73.13,
#  'Engraved Wooden Keepsake Box': 100.32,
#  'Personalized Cutting Board': 114.87,
#  'Custom Photo Pillow': 121.82,
#  'Custom Printed T-Shirt': 105.17,
#  'Personalized Hoodie': 89.47,
#  'Custom Coffee Mug': 88.99,
#  'Personalized Phone Case': 12.67,
#  'Custom Tote Bag': 11.83,
#  'Personalized Children’s Storybook': 29.97,
#  'Custom Name Puzzle Book': 108.96,
#  'Personalized Birthday Storybook': 139.38}

# %%
ecommerce['product_name'] = np.random.choice(products, size=len(ecommerce))

ecommerce['item_price'] = ecommerce['product_name'].map(price_dict)

# %%
quantity_dict = {qunty: random.randint(6, 300) for qunty in products}
quantity_dict
# Out:
# {'FreePrints 4x6 Photo Print': 71,
#  'FreePrints Square Photo Print': 236,
#  'FreePrints Glossy Photo Print': 299,
#  'FreePrints Matte Photo Print': 282,
#  'FreePrints 8x10 Photo Print': 285,
#  'FreePrints Hardcover Photobook': 161,
#  'FreePrints Softcover Photobook': 227,
#  'FreePrints Layflat Photobook': 222,
#  'FreePrints Mini Photobook': 22,
#  'FreePrints Wall Calendar': 36,
#  'Personalized Holiday Greeting Card': 98,
#  'Custom Wedding Invitation Card': 122,
#  'Birth Announcement Card': 70,
#  'Thank You Card with Photo': 223,
#  'Foil-Pressed Greeting Card': 262,
#  'Personalized Business Card': 288,
#  'Personalized Photo Mug': 293,
#  'Custom Name Necklace': 133,
#  'Personalized Photo Blanket': 209,
#  'Engraved Wooden Keepsake Box': 23,
#  'Personalized Cutting Board': 27,
#  'Custom Photo Pillow': 128,
#  'Custom Printed T-Shirt': 21,
#  'Personalized Hoodie': 63,
#  'Custom Coffee Mug': 27,
#  'Personalized Phone Case': 125,
#  'Custom Tote Bag': 7,
#  'Personalized Children’s Storybook': 219,
#  'Custom Name Puzzle Book': 112,
#  'Personalized Birthday Storybook': 213}

# %%
ecommerce['quantity'] = ecommerce['product_name'].map(quantity_dict)

# %%
ecommerce['revenue'] = round(ecommerce['item_price'] * ecommerce['quantity'], 2)

# %%
ecommerce['email'] = ecommerce['customer_name'].str.split().str[0] + '@example.com'
ecommerce['email']
# Out:
# 0            Paula@example.com
# 1             Lisa@example.com
# 2           Gerald@example.com
# 3      Christopher@example.com
# 4      Christopher@example.com
#                 ...
# 995       Jennifer@example.com
# 996       Victoria@example.com
# 997            Kim@example.com
# 998        Kathryn@example.com
# 999          Emily@example.com
# Name: email, Length: 1000, dtype: object

# %%
country = []
for _ in range(1000):
    fakeccountry= fake.country()
    country.append(fakeccountry)
    
ecommerce['country'] = pd.Series(country, name='country')

# %%
ecommerce['quantity'].unique()
# Out:
# array([ 23, 293, 125,  70, 219, 285,  21, 213,  71, 128, 282,  36, 133,
#        223, 122, 112, 161, 262,  27,   7, 236, 227, 222,  63, 299,  98,
#         22, 209, 288])

# %%
ecommerce['quantity'].describe().round(2)
# Out:
# count    1000.00
# mean      146.04
# std        97.67
# min         7.00
# 25%        63.00
# 50%       128.00
# 75%       223.00
# max       299.00
# Name: quantity, dtype: float64

# %%
ecommerce['customer_type'] = ecommerce['quantity'].apply(lambda x: 'low_volume_buyer' if x <= 78 else 'medium_volume_buyer' if x <= 146 else 'high_volume_buyer' if x <= 220 else 'top_buyer_vip' if x <= 286 else 'ultra_vip_elite' if x > 286 else x)

# %%
product_costs = {
    "FreePrints 4x6 Photo Print": 0.10,
    "FreePrints Square Photo Print": 0.15,
    "FreePrints Glossy Photo Print": 0.20,
    "FreePrints Matte Photo Print": 0.20,
    "FreePrints 8x10 Photo Print": 0.50,
    "FreePrints Hardcover Photobook": 5.00,
    "FreePrints Softcover Photobook": 3.50,
    "FreePrints Layflat Photobook": 8.00,
    "FreePrints Mini Photobook": 2.50,
    "FreePrints Wall Calendar": 3.00,
    "Personalized Holiday Greeting Card": 1.50,
    "Custom Wedding Invitation Card": 1.00,
    "Birth Announcement Card": 1.00,
    "Thank You Card with Photo": 1.25,
    "Foil-Pressed Greeting Card": 2.00,
    "Personalized Business Card": 0.50,
    "Personalized Photo Mug": 3.00,
    "Custom Name Necklace": 5.50,
    "Personalized Photo Blanket": 12.00,
    "Engraved Wooden Keepsake Box": 7.50,
    "Personalized Cutting Board": 6.00,
    "Custom Photo Pillow": 8.00,
    "Custom Printed T-Shirt": 7.00,
    "Personalized Hoodie": 15.00,
    "Custom Coffee Mug": 3.50,
    "Personalized Phone Case": 4.00,
    "Custom Tote Bag": 5.00,
    "Personalized Children’s Storybook": 8.00,
    "Custom Name Puzzle Book": 6.50,
    "Personalized Birthday Storybook": 9.00
}

# %%
ecommerce['product_cost'] = ecommerce['product_name'].map(product_costs)

# %%
ecommerce['product_cost']
# Out:
# 0       7.50
# 1       3.00
# 2       4.00
# 3       1.00
# 4       8.00
#        ...
# 995    15.00
# 996     0.15
# 997     3.00
# 998     0.20
# 999     0.10
# Name: product_cost, Length: 1000, dtype: float64

# %%
ecommerce['platform_name'] = ecommerce['channel_name'].apply(lambda v: 'Google Ads' if v == 'Paid_Search' else 'Facebook Ads' if v == 'Social' else 'Instagram Ads' if v == 'Social' else 'Mailchimp' if v == 'Email' else v)

platform_dict = {
    'Google Ads': 'PLT1',
    'Facebook Ads': 'PLT2',
    'Instagram Ads': 'PLT3',
    'Mailchimp': 'PLT4'
}

ecommerce['platform_id'] = ecommerce['platform_name'].map(platform_dict)

# %%
def random_spend(platform):
    if platform == 'Google Ads':
        return round(random.uniform(40, 120), 2)
    elif platform == 'Facebook Ads':
        return round(random.uniform(25, 100), 2)
    elif platform == 'Instagram Ads':
        return round(random.uniform(20, 90), 2)
    elif platform == 'Mailchimp':
        return round(random.uniform(5, 30), 2)
    else:
        return 0 

ecommerce['spend'] = ecommerce['platform_name'].apply(random_spend)

# %%
ecommerce['clicks'] = np.random.randint(30, 121, size=len(ecommerce))

# %%
ecommerce['orders'] = ecommerce['platform_name'].apply(lambda v: random.randint(12, 50))

# %%
product_category = {
    "FreePrints 4x6 Photo Print": "Photo Prints",
    "FreePrints Square Photo Print": "Photo Prints",
    "FreePrints Glossy Photo Print": "Photo Prints",
    "FreePrints Matte Photo Print": "Photo Prints",
    "FreePrints 8x10 Photo Print": "Photo Prints",
    "FreePrints Hardcover Photobook": "Photobooks",
    "FreePrints Softcover Photobook": "Photobooks",
    "FreePrints Layflat Photobook": "Photobooks",
    "FreePrints Mini Photobook": "Photobooks",
    "FreePrints Wall Calendar": "Calendars",
    "Personalized Holiday Greeting Card": "Greeting Cards",
    "Custom Wedding Invitation Card": "Greeting Cards",
    "Birth Announcement Card": "Greeting Cards",
    "Thank You Card with Photo": "Greeting Cards",
    "Foil-Pressed Greeting Card": "Greeting Cards",
    "Personalized Business Card": "Business Cards",
    "Personalized Photo Mug": "Drinkware",
    "Custom Name Necklace": "Jewelry",
    "Personalized Photo Blanket": "Home Decor",
    "Engraved Wooden Keepsake Box": "Home Decor",
    "Personalized Cutting Board": "Kitchenware",
    "Custom Photo Pillow": "Home Decor",
    "Custom Printed T-Shirt": "Apparel",
    "Personalized Hoodie": "Apparel",
    "Custom Coffee Mug": "Drinkware",
    "Personalized Phone Case": "Accessories",
    "Custom Tote Bag": "Accessories",
    "Personalized Children’s Storybook": "Books",
    "Custom Name Puzzle Book": "Books",
    "Personalized Birthday Storybook": "Books"
}

category_dim = pd.DataFrame({
    'product_name': list(product_category.keys()),
    'category': list(product_category.values())
})

ecommerce['category'] = ecommerce['product_name'].map(product_category)

# %%
ecommerce
# Out:
#     customer_id product_id   order_id      order_item_id campaign_id  \
# 0     CUST31529  PROD52816  ORDR73151     ORDR0066487-01    CMP71497
# 1     CUST38668  PROD19552  ORDR32717     ORDR0066487-02    CMP19223
# 2     CUST07033  PROD65121  ORDR65690     ORDR0066487-03    CMP15887
# 3     CUST88180  PROD48112  ORDR54506     ORDR0066487-04    CMP78136
# 4     CUST54526  PROD19552  ORDR03217     ORDR0066487-05    CMP77524
# ..          ...        ...        ...                ...         ...
# 995   CUST77971  PROD08816  ORDR44683   ORDR0066487-0996    CMP00714
# 996   CUST99719  PROD88120  ORDR62444   ORDR0066487-0997    CMP64084
# 997   CUST32311  PROD26075  ORDR17848   ORDR0066487-0998    CMP57341
# 998   CUST30383  PROD79582  ORDR95917   ORDR0066487-0999    CMP51784
# 999   CUST57265  PROD53436  ORDR37040  ORDR0066487-01000    CMP60018
#
#           customer_name        date                       product_name  \
# 0            Paula Cruz  2024-06-19       Engraved Wooden Keepsake Box
# 1           Lisa Cooper  2025-04-01             Personalized Photo Mug
# 2          Gerald Burke  2025-10-17            Personalized Phone Case
# 3     Christopher Scott  2025-11-25            Birth Announcement Card
# 4    Christopher Thomas  2023-12-25  Personalized Children’s Storybook
# ..                  ...         ...                                ...
# 995      Jennifer Smith  2025-11-10                Personalized Hoodie
# 996    Victoria Garrett  2025-11-21      FreePrints Square Photo Print
# 997       Kim Banks DDS  2024-10-14           FreePrints Wall Calendar
# 998       Kathryn Young  2025-11-24       FreePrints Matte Photo Print
# 999         Emily Gates  2024-01-24         FreePrints 4x6 Photo Print
#
#     channel_name channel_id  ...                    email  \
# 0    Paid_Search    CHNL_02  ...        Paula@example.com
# 1    Paid_Search    CHNL_02  ...         Lisa@example.com
# 2         Social    CHNL_01  ...       Gerald@example.com
# 3          Email    CHNL_03  ...  Christopher@example.com
# 4         Social    CHNL_01  ...  Christopher@example.com
# ..           ...        ...  ...                      ...
# 995        Email    CHNL_03  ...     Jennifer@example.com
# 996  Paid_Search    CHNL_02  ...     Victoria@example.com
# 997        Email    CHNL_03  ...          Kim@example.com
# 998       Social    CHNL_01  ...      Kathryn@example.com
# 999       Social    CHNL_01  ...        Emily@example.com
#
#                       country        customer_type product_cost platform_name  \
# 0    Central African Republic     low_volume_buyer         7.50    Google Ads
# 1                     Liberia      ultra_vip_elite         3.00    Google Ads
# 2                     Andorra  medium_volume_buyer         4.00  Facebook Ads
# 3                    Paraguay     low_volume_buyer         1.00     Mailchimp
# 4    Central African Republic    high_volume_buyer         8.00  Facebook Ads
# ..                        ...                  ...          ...           ...
# 995           Kyrgyz Republic     low_volume_buyer        15.00     Mailchimp
# 996                Madagascar        top_buyer_vip         0.15    Google Ads
# 997                  Paraguay     low_volume_buyer         3.00     Mailchimp
# 998                 Argentina        top_buyer_vip         0.20  Facebook Ads
# 999                     Sudan     low_volume_buyer         0.10  Facebook Ads
#
#     platform_id   spend clicks orders        category
# 0          PLT1  113.00     40     38      Home Decor
# 1          PLT1   45.53     63     32       Drinkware
# 2          PLT2   49.68     97     46     Accessories
# 3          PLT4   26.92     32     27  Greeting Cards
# 4          PLT2   69.17    109     31           Books
# ..          ...     ...    ...    ...             ...
# 995        PLT4    7.73     98     13         Apparel
# 996        PLT1  100.94     62     14    Photo Prints
# 997        PLT4   26.28    118     21       Calendars
# 998        PLT2   90.67    104     41    Photo Prints
# 999        PLT2   80.28     85     16    Photo Prints
#
# [1000 rows x 23 columns]

# %%
ecommerce = ecommerce[[
    'order_id',
    'order_item_id',
    'customer_id',
    'product_id',
    'campaign_id',
    'channel_id',
    'platform_id',
    'date',
    'customer_name',
    'email',
    'customer_type',
    'country',
    'product_name',
    'category',
    'item_price',
    'quantity',
    'channel_name',
    'platform_name',
    'spend',
    'clicks',
    'orders',
    'revenue']]

# %%
ecommerce.head()
# Out:
#     order_id   order_item_id customer_id product_id campaign_id channel_id  \
# 0  ORDR73151  ORDR0066487-01   CUST31529  PROD52816    CMP71497    CHNL_02
# 1  ORDR32717  ORDR0066487-02   CUST38668  PROD19552    CMP19223    CHNL_02
# 2  ORDR65690  ORDR0066487-03   CUST07033  PROD65121    CMP15887    CHNL_01
# 3  ORDR54506  ORDR0066487-04   CUST88180  PROD48112    CMP78136    CHNL_03
# 4  ORDR03217  ORDR0066487-05   CUST54526  PROD19552    CMP77524    CHNL_01
#
#   platform_id        date       customer_name                    email  ...  \
# 0        PLT1  2024-06-19          Paula Cruz        Paula@example.com  ...
# 1        PLT1  2025-04-01         Lisa Cooper         Lisa@example.com  ...
# 2        PLT2  2025-10-17        Gerald Burke       Gerald@example.com  ...
# 3        PLT4  2025-11-25   Christopher Scott  Christopher@example.com  ...
# 4        PLT2  2023-12-25  Christopher Thomas  Christopher@example.com  ...
#
#                         product_name        category item_price quantity  \
# 0       Engraved Wooden Keepsake Box      Home Decor     100.32       23
# 1             Personalized Photo Mug       Drinkware      97.59      293
# 2            Personalized Phone Case     Accessories      12.67      125
# 3            Birth Announcement Card  Greeting Cards     143.38       70
# 4  Personalized Children’s Storybook           Books      29.97      219
#
#    channel_name  platform_name   spend clicks  orders   revenue
# 0   Paid_Search     Google Ads  113.00     40      38   2307.36
# 1   Paid_Search     Google Ads   45.53     63      32  28593.87
# 2        Social   Facebook Ads   49.68     97      46   1583.75
# 3         Email      Mailchimp   26.92     32      27  10036.60
# 4        Social   Facebook Ads   69.17    109      31   6563.43
#
# [5 rows x 22 columns]

# %%
ecommerce.columns
# Out:
# Index(['order_id', 'order_item_id', 'customer_id', 'product_id', 'campaign_id',
#        'channel_id', 'platform_id', 'date', 'customer_name', 'email',
#        'customer_type', 'country', 'product_name', 'category', 'item_price',
#        'quantity', 'channel_name', 'platform_name', 'spend', 'clicks',
#        'orders', 'revenue'],
#       dtype='object')

# %%
ecommerce.to_csv('C:/Users/loydt/Downloads/ecommerce.csv', index=False)
